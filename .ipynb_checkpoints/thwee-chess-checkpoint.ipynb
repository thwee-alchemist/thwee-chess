// %%
/*
  index.js
  Joshua Marshall Moore
  July 12th, 2018

  North Las Vegas, Nevada

  Goal of this server is to relay messages between chess players. 
*/

const express = require('express');
const path = require('path');
const PORT = process.env.PORT || 5000;
var app = express();
var http = require('http').Server(app);
var io = require('socket.io')(http);

app.use(express.static(path.join(__dirname, 'public')));

var tables = new Map();

http.listen(PORT, function(){
  console.log(`listening on ${PORT}`);
});

io.on('connection', function(socket){
  console.log('a user connected');

  socket.on('table', function(info){
    console.log(info);
    socket.join(info.table);

    socket.room = info.table;
    
    if(!tables.has(info.table)){
      tables.set(info.table, {
        name: info.table,
        board: info.board,
        sockets: [socket]
      });
    }else{
      socket.to(info.table).emit('board', info.board);
    }
  });
  
  socket.on('board-piece-position', info => {
    console.log('board-piece-position', info);
    socket.to(info.board).emit('piece-move', info.piece)
    tables.get(socket.room).board[info.piece.id].position = info.piece.position;
  });

  socket.on('disconnect', function(){
    console.log('user disconnected');
    console.log(socket.rooms);
  });
});

1==1;
// Out:
// true
// listening on 5000
// a user connected
// a user connected
// { table: '', board: { undefined: {} } }
// { table: 'room', board: { undefined: {} } }
// board-piece-position { board: 'room',
//   piece: { id: 'white-king', position: { top: 139.875, left: 269 } } }
// TypeError: Cannot set property 'position' of undefined
//     at Socket.socket.on.info (evalmachine.<anonymous>:49:59)
//     at emitOne (events.js:96:13)
//     at Socket.emit (events.js:188:7)
//     at /home/jmoore/thwee-chess/node_modules/socket.io/lib/socket.js:528:12
//     at _combinedTickCallback (internal/process/next_tick.js:73:7)
//     at process._tickCallback (internal/process/next_tick.js:104:9)
// user disconnected
// {}
// a user connected
// { table: 'room', board: { undefined: {} } }
// user disconnected
// {}
// a user connected
// user disconnected
// {}
// a user connected
// { table: 'room', board: { undefined: {} } }
// user disconnected
// {}
// a user connected
// { table: 'room', board: { undefined: {} } }
// { table: 'test', board: { undefined: {} } }
// user disconnected
// {}
// a user connected
// user disconnected
// {}
// a user connected
// user disconnected
// {}
// a user connected
// { table: 'room',
//   board:
//    { 'white-king': { id: 'white-king', position: [Object] },
//      'white-queen': { id: 'white-queen', position: [Object] },
//      'white-bishop-1': { id: 'white-bishop-1', position: [Object] },
//      'white-bishop-2': { id: 'white-bishop-2', position: [Object] },
//      'white-knight-1': { id: 'white-knight-1', position: [Object] },
//      'white-knight-2': { id: 'white-knight-2', position: [Object] },
//      'white-castle-1': { id: 'white-castle-1', position: [Object] },
//      'white-castle-2': { id: 'white-castle-2', position: [Object] },
//      'white-pawn-1': { id: 'white-pawn-1', position: [Object] },
//      'white-pawn-2': { id: 'white-pawn-2', position: [Object] },
//      'white-pawn-3': { id: 'white-pawn-3', position: [Object] },
//      'white-pawn-4': { id: 'white-pawn-4', position: [Object] },
//      'white-pawn-5': { id: 'white-pawn-5', position: [Object] },
//      'white-pawn-6': { id: 'white-pawn-6', position: [Object] },
//      'white-pawn-7': { id: 'white-pawn-7', position: [Object] },
//      'white-pawn-8': { id: 'white-pawn-8', position: [Object] },
//      'black-king': { id: 'black-king', position: [Object] },
//      'black-queen': { id: 'black-queen', position: [Object] },
//      'black-bishop-1': { id: 'black-bishop-1', position: [Object] },
//      'black-bishop-2': { id: 'black-bishop-2', position: [Object] },
//      'black-knight-1': { id: 'black-knight-1', position: [Object] },
//      'black-knight-2': { id: 'black-knight-2', position: [Object] },
//      'black-castle-1': { id: 'black-castle-1', position: [Object] },
//      'black-castle-2': { id: 'black-castle-2', position: [Object] },
//      'black-pawn-1': { id: 'black-pawn-1', position: [Object] },
//      'black-pawn-2': { id: 'black-pawn-2', position: [Object] },
//      'black-pawn-3': { id: 'black-pawn-3', position: [Object] },
//      'black-pawn-4': { id: 'black-pawn-4', position: [Object] },
//      'black-pawn-5': { id: 'black-pawn-5', position: [Object] },
//      'black-pawn-6': { id: 'black-pawn-6', position: [Object] },
//      'black-pawn-7': { id: 'black-pawn-7', position: [Object] },
//      'black-pawn-8': { id: 'black-pawn-8', position: [Object] } } }
